# %%
import os 
import selenium 
from selenium import webdriver
import requests 
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(ChromeDriverManager().install()) # temporary cache
url = ("https://www.google.com/search?q={a}+{q}+lyrics&rlz=1C1YTUH_enIN1014IN1014&sxsrf=ALiCzsZqaEHYmMFAD8CDKEvBCyRAOZaGYg%3A1664275547573&ei=W9QyY6TPIqa0z7sP7MyekA4&ved=0ahUKEwjk6MjG5bT6AhUm2nMBHWymB-IQ4dUDCA4&uact=5&oq=Jaden+Smith+cabin+fever+lyrics&gs_lcp=Cgdnd3Mtd2l6EAMyBQgAEIAEMgYIABAeEAgyBQgAEIYDOgYIABAeEAc6CAgAEB4QCBAHSgQIQRgASgQIRhgAUABYwwdgiQ5oAHABeACAAYMBiAHyAZIBAzAuMpgBAKABAqABAcABAQ&sclient=gws-wiz")
item=input("Enter name of song u want search => ")
item1=input("Please enter the singer name =>")
driver.get(url.format(a=item1,q=item))
lyrics =driver.find_elements(By.CSS_SELECTOR, '.Z1hOCe .ujudUb span')
lyrics_list = []
for i in lyrics:    
    lyrics_list.append(i.text)
driver.quit()
print(*lyrics_list, sep = "\n")
f=open("{} lyrics.txt".format(item),"a+")
for i in lyrics_list :
    f.write("%s\n" % i)
f.close()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9564\2032468816.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install()) # temporary cache
# Enter name of song u want search => Monster
# Please enter the singer name =>Eminem
# I'm friends with the monster that's under my bed
# Get along with the voices inside of my head
# You're tryin' to save me, stop holding your breath
# And you think I'm crazy, yeah, you think I'm crazy (crazy)
# I wanted the fame but not the cover of Newsweek
# Oh well, guess beggars can't be choosey
# Wanted to receive attention for my music
# Wanted to be left alone in public, excuse me
# For wantin' my cake, and eat it too, and wantin' it both ways
# Fame made me a balloon 'cause my ego inflated
# When I blew, see, but it was confusing
# 'Cause all I wanted to do's be the Bruce Lee of loose leaf
# Abused ink, used it as a tool when I blew steam (ooh)
# ...

# %%
import os.path

if os.path.exists('Song data.csv'):
    f=open("Song data.csv","a+")
    s=item+","+item1+"\n"
    f.write(s)
    f.close()
else:
    f=open("Song data.csv","w+")
    f.write("Song Name,Singer \n")
    f.close()
    f=open("Song data.csv","a+") 
    s=item+","+item1+"\n"
    f.write(s)
    f.close()
